# %% [markdown]
# # Phase 02 — Ablation Study (Soil / Climate / Topo)
# Full notebook in Drive: `AARN_project/notebooks/NewModel_phase02-Abdou.ipynb`
# Open in Colab: https://colab.research.google.com/drive/1K15Dg8YP9Uzxzi34qU6btmQEjnq6Sina
