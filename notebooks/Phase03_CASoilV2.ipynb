# %% [markdown]
# # Phase 03 — MCTNetCASoilV2
# Full notebook in Drive: `AARN_project/notebooks/Model-Phase03.ipynb`
# Open in Colab: https://colab.research.google.com/drive/1MjbA9KknHhIhcf6Gx-To2G28Olhuu7IE
